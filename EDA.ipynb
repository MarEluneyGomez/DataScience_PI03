# %% [markdown]
# Previamente, dentro de la pagina de ENACOM, fui seleccionando los csv que a mi parecer eran mas relevantes para el analisis a nivel nacional de acceso a servicios de telecomunicacion.
# Ahora echare un vistazo a los csv para ver que datos contienen exactamente y si efectivamente me seran utiles o no.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Abro los CSV relacionados con el internet para darme un pantallaso general de sus datos

# %%
df_internet_penetracion = pd.read_csv('CSVs/Internet_Penetracion.csv')
df_internet_acceso_velocidad = pd.read_csv('CSVs/Internet_Accesos-por-velocidad.csv')
df_internet_historico_velocidad = pd.read_csv('CSVs/historico_velocidad_internet.csv')

# %%
df_internet_penetracion
# Out:
#       Año  Trimestre            Provincia Accesos por cada 100 hogares
# 0    2022          2         Buenos Aires                        77,58
# 1    2022          2      Capital Federal                       121,31
# 2    2022          2            Catamarca                         62,4
# 3    2022          2                Chaco                        43,79
# 4    2022          2               Chubut                        83,19
# ..    ...        ...                  ...                          ...
# 811  2014          1           Santa Cruz                        28,94
# 812  2014          1             Santa Fe                        47,85
# 813  2014          1  Santiago Del Estero                        16,31
# 814  2014          1     Tierra Del Fuego                        63,97
# 815  2014          1              Tucumán                        33,42
#
# [816 rows x 4 columns]

# %%
df_internet_acceso_velocidad
# Out:
#       Año  Trimestre            Provincia  HASTA 512 kbps  \
# 0    2022          2         Buenos Aires          30.639
# 1    2022          2      Capital Federal         517.000
# 2    2022          2            Catamarca          71.000
# 3    2022          2                Chaco         461.000
# 4    2022          2               Chubut         109.000
# ..    ...        ...                  ...             ...
# 811  2014          1           Santa Cruz         161.000
# 812  2014          1             Santa Fe           8.456
# 813  2014          1  Santiago Del Estero           1.234
# 814  2014          1     Tierra Del Fuego          12.000
# 815  2014          1              Tucumán           6.000
#
#      + 512 Kbps - 1 Mbps + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  \
# 0                 28.323           295.238             307.554
# 1                  5.980            36.036              72.434
# 2                413.000             3.678               6.155
# ...

# %%
df_internet_historico_velocidad
# Out:
#       Año  Trimestre            Provincia  Mbps (Media de bajada)
# 0    2022          2         Buenos Aires                      66
# 1    2022          2      Capital Federal                      94
# 2    2022          2            Catamarca                      57
# 3    2022          2                Chaco                      51
# 4    2022          2               Chubut                      15
# ..    ...        ...                  ...                     ...
# 811  2014          1           Santa Cruz                       3
# 812  2014          1             Santa Fe                       3
# 813  2014          1  Santiago Del Estero                       3
# 814  2014          1     Tierra Del Fuego                       3
# 815  2014          1              Tucumán                       3
#
# [816 rows x 4 columns]

# %% [markdown]
# De entre estos descartare el df 'df_internet_historico_velocidad' ya que 'df_internet_acceso_velocidad' tiene muchos mas datos que el, ademas de compartir muchos otros.

# %% [markdown]
# Visualizo en busca de duplicados y nulos en los df que decidi quedarme

# %%
df_internet_acceso_velocidad[df_internet_acceso_velocidad.duplicated(keep=False)]
#No hay duplicados
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, HASTA 512 kbps, + 512 Kbps - 1 Mbps, + 1 Mbps - 6 Mbps, + 6 Mbps - 10 Mbps, + 10 Mbps - 20 Mbps, + 20 Mbps - 30 Mbps, + 30 Mbps, OTROS, Total]
# Index: []

# %%
df_internet_acceso_velocidad.isnull().sum()
# Out:
# Año                    0
# Trimestre              0
# Provincia              0
# HASTA 512 kbps         0
# + 512 Kbps - 1 Mbps    0
# + 1 Mbps - 6 Mbps      0
# + 6 Mbps - 10 Mbps     0
# + 10 Mbps - 20 Mbps    0
# + 20 Mbps - 30 Mbps    0
# + 30 Mbps              0
# OTROS                  6
# Total                  0
# dtype: int64

# %%
df_internet_penetracion[df_internet_penetracion.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Accesos por cada 100 hogares]
# Index: []

# %%
df_internet_penetracion.isnull().sum()
# Out:
# Año                             0
# Trimestre                       0
# Provincia                       0
# Accesos por cada 100 hogares    0
# dtype: int64

# %% [markdown]
# Abro los CSV relacionados con la television para darme un pantallaso general de sus datos

# %%
df_television = pd.read_csv('CSVs/Television.csv')
df_television_penetracion = pd.read_csv('CSVs/Television_Penetracion.csv')
df_television_suscripcion_x_c_100 = pd.read_csv('CSVs/Television_suscripcion_cada_100.csv')
df_television_suscripcion_provincia = pd.read_csv('CSVs/Television_Suscripcion_Provincia.csv')

# %%
df_television
# Out:
#       Año  Trimestre            Provincia  \
# 0    2022          1         Buenos Aires
# 1    2022          1      Capital Federal
# 2    2022          1            Catamarca
# 3    2022          1                Chaco
# 4    2022          1               Chubut
# ..    ...        ...                  ...
# 787  2014          1           Santa Cruz
# 788  2014          1             Santa Fe
# 789  2014          1  Santiago del Estero
# 790  2014          1     Tierra del Fuego
# 791  2014          1              Tucumán
#
#     Accesos TV por suscripción por cada 100 hab  \
# 0                                          16,7
# 1                                         24,19
# 2                                         11,18
# 3                                          9,78
# 4                                         12,22
# ..                                          ...
# 787                                        6,79
# 788                                       16,22
# ...

# %%
df_television_penetracion
# Out:
#      Año  Trimestre Accesos TV por suscripción por cada 100 hab  \
# 0   2022          1                                       16,41
# 1   2021          4                                       16,52
# 2   2021          3                                       16,73
# 3   2021          2                                       16,02
# 4   2021          1                                       16,09
# 5   2020          4                                        16,1
# 6   2020          3                                       16,13
# 7   2020          2                                       15,93
# 8   2020          1                                       15,97
# 9   2019          4                                       16,17
# 10  2019          3                                        15,9
# 11  2019          2                                        15,7
# 12  2019          1                                       15,58
# 13  2018          4                                       15,47
# ...

# %%
df_television_suscripcion_provincia
# Out:
#       Año  Trimestre            Provincia Accesos TV por suscripción
# 0    2022          1         Buenos Aires                  2.975.672
# 1    2022          1      Capital Federal                    745.263
# 2    2022          1            Catamarca                     47.123
# 3    2022          1                Chaco                    119.743
# 4    2022          1               Chubut                     77.728
# ..    ...        ...                  ...                        ...
# 787  2014          1           Santa Cruz                     21.133
# 788  2014          1             Santa Fe                    546.523
# 789  2014          1  Santiago del Estero                     92.972
# 790  2014          1     Tierra del Fuego                     29.886
# 791  2014          1              Tucumán                    111.552
#
# [792 rows x 4 columns]

# %%
df_television_suscripcion_x_c_100
# Out:
#       Año  Trimestre            Provincia  \
# 0    2022          1         Buenos Aires
# 1    2022          1      Capital Federal
# 2    2022          1            Catamarca
# 3    2022          1                Chaco
# 4    2022          1               Chubut
# ..    ...        ...                  ...
# 787  2014          1           Santa Cruz
# 788  2014          1             Santa Fe
# 789  2014          1  Santiago del Estero
# 790  2014          1     Tierra del Fuego
# 791  2014          1              Tucumán
#
#     Accesos TV por suscripción por cada 100 hab  \
# 0                                          16,7
# 1                                         24,19
# 2                                         11,18
# 3                                          9,78
# 4                                         12,22
# ..                                          ...
# 787                                        6,79
# 788                                       16,22
# ...

# %% [markdown]
# De estos df me quedare con 3: 'df_television_penetracion', 'df_television_suscripcion_provincia' y 'df_television'. Ya que la informacion de 'df_television_suscripcion_x_c_100' se encuentra en los otros df ya.

# %%
##Al final solo use 2 al momento del analisis en Power bi

# %% [markdown]
# Visualizo en busca de duplicados y nulos en los df que decidi quedarme

# %%
df_television_suscripcion_provincia.isnull().sum()
# Out:
# Año                           0
# Trimestre                     0
# Provincia                     0
# Accesos TV por suscripción    0
# dtype: int64

# %%
df_television_penetracion.isnull().sum()
# Out:
# Año                                                0
# Trimestre                                          0
# Accesos TV por suscripción por cada 100 hab        0
# Accesos TV satelital por cada 100 hab              0
# Accesos TV por suscripción por cada 100 hogares    0
# Accesos TV satelital por cada 100 hogares          0
# dtype: int64

# %%
df_television.isnull().sum()
# Out:
# Año                                                0
# Trimestre                                          0
# Provincia                                          0
# Accesos TV por suscripción por cada 100 hab        0
# Accesos TV por suscripción por cada 100 hogares    0
# dtype: int64

# %%
df_television[df_television.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Accesos TV por suscripción por cada 100 hab, Accesos TV por suscripción por cada 100 hogares]
# Index: []

# %%
df_television_penetracion[df_television_penetracion.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Accesos TV por suscripción por cada 100 hab, Accesos TV satelital por cada 100 hab, Accesos TV por suscripción por cada 100 hogares, Accesos TV satelital por cada 100 hogares]
# Index: []

# %%
df_television_suscripcion_provincia[df_television_suscripcion_provincia.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Accesos TV por suscripción]
# Index: []

# %% [markdown]
# Abro los CSV relacionados con la telefonia movil para darme un pantallaso general de sus datos

# %%
df_telefonia_movil = pd.read_csv('CSVs/Telefonia_movil.csv')
df_telefonia_movil_Tipo_acceso = pd.read_csv('CSVs/Telefonia_movil_Tipo_acceso.csv')
df_portabilidad = pd.read_csv('CSVs/Portabilidad.csv')

# %%
df_telefonia_movil
# Out:
#      Año  Trimestre  Accesos por cada 100 hab        Periodo
# 0   2013          1                       154   Ene-Mar 2013
# 1   2013          2                       156   Abr-Jun 2013
# 2   2013          3                       159  Jul-Sept 2013
# 3   2013          4                       159   Oct-Dic 2013
# 4   2014          1                       148   Ene-Mar 2014
# 5   2014          2                       143   Abr-Jun 2014
# 6   2014          3                       143  Jul-Sept 2014
# 7   2014          4                       143   Oct-Dic 2014
# 8   2015          1                       140   Ene-Mar 2015
# 9   2015          2                       139   Abr-Jun 2015
# 10  2015          3                       141  Jul-Sept 2015
# 11  2015          4                       143   Oct-Dic 2015
# 12  2016          1                       142   Ene-Mar 2016
# 13  2016          2                       143   Abr-Jun 2016
# ...

# %%
df_telefonia_movil_Tipo_acceso
# Out:
#      Año  Trimestre Total de accesos pospago Total de accesos prepago  \
# 0   2013          1                7.761.349               57.147.608
# 1   2013          2                7.769.110               58.004.822
# 2   2013          3                8.002.183               59.048.909
# 3   2013          4                8.674.516               58.894.516
# 4   2014          1                8.224.482               54.725.089
# 5   2014          2                7.953.775               53.009.865
# 6   2014          3                8.214.424               53.102.043
# 7   2014          4                8.027.505               53.093.330
# 8   2015          1                7.747.230               52.474.633
# 9   2015          2                7.633.527               52.241.939
# 10  2015          3                7.600.799               53.131.712
# 11  2015          4                7.594.526               54.247.485
# ...

# %%
df_portabilidad
# Out:
#       Año  Mes  Personal   Claro   Nextel  Movistar Periodo
# 0    2012    3   -17.000  19.000    0.000    -2.000  Mar-12
# 1    2012    4     3.508  -1.134 -189.000    -2.185  Apr-12
# 2    2012    5     1.253   4.792 -853.000    -5.192  May-12
# 3    2012    6     3.263  -1.248 -848.000    -1.167  Jun-12
# 4    2012    7     5.554  -3.847   -1.105  -602.000  Jul-12
# ..    ...  ...       ...     ...      ...       ...     ...
# 115  2021   10     3.093  10.566      NaN   -13.659  Oct-21
# 116  2021   11     6.372  12.306      NaN   -18.678  Nov-21
# 117  2021   12   591.000   9.875      NaN   -10.466  Dec-21
# 118  2022    1    15.316  -5.775      NaN    -9.541  Jan-22
# 119  2022    2     8.433   7.222      NaN   -15.655  Feb-22
#
# [120 rows x 7 columns]

# %% [markdown]
# De estos 3 df me quedare con todos, ya que considero que todos tienen informacion unica y relevante

# %% [markdown]
# Visualizo en busca de duplicados y nulos

# %%
df_telefonia_movil.isnull().sum()
# Out:
# Año                         0
# Trimestre                   0
# Accesos por cada 100 hab    0
# Periodo                     0
# dtype: int64

# %%
df_telefonia_movil_Tipo_acceso.isnull().sum()
# Out:
# Año                            0
# Trimestre                      0
# Total de accesos pospago       0
# Total de accesos prepago       0
# Total de accesos operativos    0
# Periodo                        0
# dtype: int64

# %%
df_portabilidad.isnull().sum()
# Out:
# Año          0
# Mes          0
# Personal     0
# Claro        0
# Nextel      50
# Movistar     0
# Periodo      0
# dtype: int64

# %%
df_telefonia_movil[df_telefonia_movil.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Accesos por cada 100 hab, Periodo]
# Index: []

# %%
df_telefonia_movil_Tipo_acceso[df_telefonia_movil_Tipo_acceso.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Total de accesos pospago, Total de accesos prepago, Total de accesos operativos, Periodo]
# Index: []

# %%
df_portabilidad[df_portabilidad.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Mes, Personal, Claro, Nextel, Movistar, Periodo]
# Index: []

# %% [markdown]
# Por ultimo Abro los CSV relacionados con la telefonia fija para darme un pantallaso general de sus datos

# %%
df_telefonia_fija = pd.read_csv('CSVs/Telefonia_fija.csv')
df_telefonia_fija_Tipo_acceso = pd.read_csv ('CSVs/telefonia_fija_Tipo_acceso.csv')

# %%
df_telefonia_fija
# Out:
#       Año  Trimestre            Provincia  \
# 0    2014          1         Buenos Aires
# 1    2014          1      Capital Federal
# 2    2014          1            Catamarca
# 3    2014          1                Chaco
# 4    2014          1               Chubut
# ..    ...        ...                  ...
# 787  2022          1           Santa Cruz
# 788  2022          1             Santa Fe
# 789  2022          1  Santiago del Estero
# 790  2022          1     Tierra del Fuego
# 791  2022          1              Tucumán
#
#     Accesos telefonía fija por cada 100 hab  \
# 0                                     26,72
# 1                                     52,66
# 2                                     10,03
# 3                                      9,09
# 4                                     17,66
# ..                                      ...
# 787                                    7,43
# 788                                   17,84
# 789                                    6,93
# ...

# %%
df_telefonia_fija_Tipo_acceso
# Out:
#       Año  Trimestre            Provincia Accesos telefonía fija (total)  \
# 0    2022          1         Buenos Aires                      3.340.707
# 1    2022          1      Capital Federal                      1.508.031
# 2    2022          1            Catamarca                         30.167
# 3    2022          1                Chaco                         84.847
# 4    2022          1               Chubut                         72.602
# ..    ...        ...                  ...                            ...
# 787  2014          1           Santa Cruz                         40.625
# 788  2014          1             Santa Fe                        770.361
# 789  2014          1  Santiago del Estero                         70.717
# 790  2014          1     Tierra del Fuego                         32.631
# 791  2014          1              Tucumán                        210.917
#
#     Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# ...

# %% [markdown]
# De estos 2 dataframes me quedare con ambos ya que ellos tienen informaciones unicas e importantes a mi parecer

# %% [markdown]
# Visualizo en busca de duplicados y nulos

# %%
df_telefonia_fija.isnull().sum()
# Out:
# Año                                            0
# Trimestre                                      0
# Provincia                                      0
# Accesos telefonía fija por cada 100 hab        0
# Accesos telefonía fija por cada 100 hogares    0
# dtype: int64

# %%
df_telefonia_fija_Tipo_acceso.isnull().sum()
# Out:
# Año                                   0
# Trimestre                             0
# Provincia                             0
# Accesos telefonía fija (total)        0
# Accesos telefonía fija (hogares)      0
# Accesos telefonía fija (comercial)    0
# Accesos telefonía fija (gobierno)     0
# Accesos telefonía fija (otros)        0
# dtype: int64

# %%
df_telefonia_fija[df_telefonia_fija.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Accesos telefonía fija por cada 100 hab, Accesos telefonía fija por cada 100 hogares]
# Index: []

# %%
df_telefonia_fija_Tipo_acceso[df_telefonia_fija_Tipo_acceso.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Año, Trimestre, Provincia, Accesos telefonía fija (total), Accesos telefonía fija (hogares), Accesos telefonía fija (comercial), Accesos telefonía fija (gobierno), Accesos telefonía fija (otros)]
# Index: []
